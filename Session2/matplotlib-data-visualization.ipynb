# %% [markdown]
# # ![](https://matplotlib.org/_static/logo2.svg)
#
# This notebook provides basic types of matplotlib graphs, used in data visualization

# %%
# !pip install jyquickhelper

# %%
# Please install jyquickhelper before running this cell by uncomment and run previous cell
from jyquickhelper import add_notebook_menu
add_notebook_menu(last_level=3)
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
# ...

# %% [markdown]
# ## 1. Why data visualization?
#
# - Human brain processes graph information faster than texts and tables
# - Easy way to convey concepts in a universal manner
# - Help to:
#     - Identify areas that need attention or improvement.
#     - Clarify which factors influence customer behavior.
#     - Help you understand which products to place where.
#     - Predict sales volumes.

# %% [markdown]
# ## 2. What and why matplotlib?
# - Matplotlib is a Python library used for plotting the beautiful and attractive Graphs
# - Uses the numpy to handle large arrays of data sets
# - Intergrates with pandas

# %%
# import to use
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Basic graph types

# %% [markdown]
# ### 3.1 Line plot
# - plot function graph
# - plot time-series data

# %%
# function graph
import numpy as np
# create data
x = np.arange(-1,3, 0.1)
y1 = x**2
y2 = np.exp(x)

plt.plot(x, y1, 'b-', label='Squared x') # plot 1st function
plt.plot(x, y2, 'r--', label='Exp(x)')   # plot 2nd function
plt.title('Function graph') # add title
plt.xlabel('x')             # add x label
plt.ylabel('y')             # add y label
plt.grid(True) # add grid
plt.legend()   # add legend
plt.show()     # show the graph

# %%
# time-series data
# create data
import pandas as pd
df = pd.read_csv('weather.csv')

# create new figure, adjust its size
plt.figure(figsize=(10,5))
plt.plot(df.MinTemp, label='Minimum temperature')
plt.plot(df.MaxTemp, label='Maximum temperature')

plt.title('Temperature') # add title
plt.xlabel('Day')             # add x label
plt.ylabel('Temperatue, degree Celsius')             # add y label
plt.grid(True) # add grid
plt.legend()   # add legend
plt.show()     # show the graph

# %% [markdown]
# ### 3.2 Scatter plot
# Used to evaluate trends and correlation between to values

# %%
# read the data
df1 = pd.read_csv('telcom.csv')
df1.MonthlyCharges.fillna(df1.MonthlyCharges.median(), inplace=True)

# plot MonthlyCharges vs TotalCharges
plt.scatter(x=df1.MonthlyCharges, y=df1.TotalCharges)
plt.xlabel('Monthly Charges')
plt.ylabel('Total Charges')
plt.show()

# %% [markdown]
# ### 3.3 Histogram
# - Show the distribution
# - Detect outliers

# %%
# Minimum temperature distribution
plt.hist(df.MinTemp, bins=15, density=True, label='Experiment') # if density=False/None, counts will be shown
plt.title('Temperature distribution')
plt.xlabel('Minimum temperature')
plt.ylabel('Density')

# # advanced part - add kde - Kernel Density Estimates
# from scipy import stats
# kde = stats.gaussian_kde(df.MinTemp)
# xx = np.arange(df.MinTemp.min(), df.MinTemp.max()+0.1, 0.1)
# plt.plot(xx,kde(xx), label='Estimated')

plt.legend()
plt.show()

# %% [markdown]
# ### 3.4 Pie plot

# %%
churn = df1.Churn.value_counts()
labels = churn.keys()
values = churn.values

# Pie graph of churn and non-churn customer
plt.pie(x=values, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Churn customer distribution')
plt.show()

# %% [markdown]
# ### 3.5 Bar plot
# Alternative line

# %%
# plot tenure vs customerID
plt.bar(df1.index, df1.tenure)
plt.xticks(df1.index, df1.customerID, rotation='vertical')
plt.xlabel('Customer ID')
plt.ylabel('Tenure')
plt.show()

# %% [markdown]
# #### Bonus
# Box plot
#
# And [more graph](https://matplotlib.org/users/screenshots.html)

# %%
plt.boxplot(x=df.MinTemp)
plt.show()

# %%
df.plot(y=['Humidity9am', 'Humidity3pm'], figsize=(15,5), title='Humidity over year, %')
plt.show()

# %%
df.plot(x='Temp3pm', y='Humidity3pm', kind='scatter', title='Humidity vs temperature at 3pm')
plt.show()

# %%
# use intergrate with pandas
df.hist(column='MaxTemp', bins=15)
plt.show()
