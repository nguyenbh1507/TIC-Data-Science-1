# %% [markdown]
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
# This notebook provides an introduction to PANDAS

# %%
# !pip install jyquickhelper

# %%
# Please install jyquickhelper before running this cell by uncomment and run previous cell
from jyquickhelper import add_notebook_menu
add_notebook_menu(last_level=3)
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 3, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## 1. What is PANDAS?
# ***pandas*** is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %% [markdown]
# ## 2. Why PANDAS?
#
# - With Python Pandas, it is easier to clean & wrangle with your Data.
# - Features of Pandas make it a great choice for Data Science and Analysis.
# - Using it with Python Libraries like Matplotlib & Numpy makes it all the more useful.
#
# ### ***pandas*** feature:
# - Merging and Joining Data Sets.
# - Reshaping & pivoting Data Sets.
# - Inserting & deleting columns in Data Structure.
# - Aligning data & dealing with missing data.
# - Iterating over a Data set.
# - Analyzing Time Series.
# - Filtering Data around a condition.
# - Arranging Data in an ascending & descending.
# - Reading from flies with CSV, TXT, XLSX, other formats.
# - Manipulating Data using integrated indexing for DataFrame objects.
# - Generating Data range, date shifting, lagging, converting frequency, and other other Time Series functionality.
# - Subsettting fancy indexing, & label based slicing Data Sets that are large in size.
# - Performing split apply combine on Data Sets using the group by engine.

# %% [markdown]
# ## 3. Basic components
# ![](https://cdncontribute.geeksforgeeks.org/wp-content/uploads/finallpandas.png)
#
# - **DataFrame** saves data in form of table
# - **Row** saves valuesof an *observation*/*datapoint*
# - **Column** saves values of a *variable*/*feature*
# - **Series** saves like-array/dictionary data with specified indices

# %% [markdown]
# ## 4. Create dataframe

# %%
import pandas as pd

# %% [markdown]
# ### 4.1 Create dataframe from list of rows

# %%
rows = [
    {'userID': 'abc', 'name': 'John Nguyen', 'dob': '1989-02-18'},
    {'userID': 'def', 'name': 'John Smith', 'dob': '1989-03-18'},
    {'userID': 'ghi', 'name': 'Alan Nguyen', 'dob': '1980-02-18'},
]
pd.DataFrame(data=rows)
# Out:
#           dob         name userID
# 0  1989-02-18  John Nguyen    abc
# 1  1989-03-18   John Smith    def
# 2  1980-02-18  Alan Nguyen    ghi

# %% [markdown]
# ### 4.2 Create dataframe from list of columns

# %%
columns = {
    'userID': ['abc', 'def', 'ghi'],
    'name': ['John Nguyen', 'John Smith', 'Alan Nguyen'],
    'dob':['1989-02-18', '1989-03-18', '1980-02-18']
}
pd.DataFrame(data=columns)
# Out:
#   userID         name         dob
# 0    abc  John Nguyen  1989-02-18
# 1    def   John Smith  1989-03-18
# 2    ghi  Alan Nguyen  1980-02-18

# %% [markdown]
# ### 4.3 Create dataframe from matrix

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
pd.DataFrame(data=matrix, index=['user1', 'user2', 'user3'], columns=['#cat', '#dog', '#bird'])
# Out:
#        #cat  #dog  #bird
# user1     1     2      3
# user2     4     5      6
# user3     7     8      9

# %% [markdown]
# ### 4.4 Create dataframe from file
# Type **pd.read** then press **tab** to see what file types are supported in pandas

# %%
# set max displayed columns to 99
pd.options.display.max_columns = 99
df = pd.read_csv('telcom.csv')
df
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            0.0     Yes         No       1           No
# 1   5575-GNVDE    Male            NaN      No         No      34          Yes
# 2   3668-QPYBK    Male            0.0      No         No       2          Yes
# 3   7795-CFOCW    Male            0.0      No         No      45           No
# 4   9237-HQITU  Female            0.0      No         No       2          Yes
# 5   9305-CDSKC  Female            0.0      No         No       8          Yes
# 6   1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 7   6713-OKOMC  Female            0.0      No         No      10           No
# 8   7892-POOKP  Female            0.0     Yes         No      28          Yes
# 9   6388-TABGU    Male            0.0      No        Yes      62          Yes
# 10  9763-GRSKD    Male            0.0     Yes        Yes      13          NaN
# 11  7469-LKBCI    Male            0.0      No         No      16          Yes
# 12  8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 13  0280-XJGEX    Male            0.0      No         No      49          Yes
# 14  5129-JLPIS    Male            0.0      No         No      25          Yes
# 15  3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 16  8191-XWSZG  Female            0.0      No         No      52          Yes
# 17  9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 18  4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#        MultipleLines InternetService       OnlineSecurity  \
# 0   No phone service             DSL                   No
# 1                 No             DSL                  Yes
# 2                 No             DSL                  Yes
# 3   No phone service             DSL                  Yes
# 4                 No     Fiber optic                   No
# 5                Yes             NaN                   No
# 6                Yes     Fiber optic                   No
# 7   No phone service             DSL                  Yes
# 8                Yes     Fiber optic                   No
# 9                 No             DSL                  Yes
# 10                No             DSL                  Yes
# 11                No              No  No internet service
# 12               Yes     Fiber optic                   No
# 13               Yes     Fiber optic                   No
# 14                No     Fiber optic                  Yes
# 15               Yes     Fiber optic                  Yes
# 16                No              No  No internet service
# 17               Yes     Fiber optic                  Yes
# 18                No             DSL                   No
#
#            OnlineBackup     DeviceProtection          TechSupport  \
# 0                   Yes                   No                   No
# 1                    No                  Yes                   No
# 2                   Yes                   No                   No
# 3                    No                  Yes                  Yes
# 4                    No                   No                   No
# 5                    No                  Yes                   No
# 6                   Yes                   No                   No
# 7                    No                   No                   No
# 8                    No                  Yes                  Yes
# 9                   Yes                   No                   No
# 10                   No                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                   No                  Yes                   No
# 13                  Yes                  Yes                   No
# 14                   No                  Yes                  Yes
# 15                  Yes                  Yes                  Yes
# 16  No internet service  No internet service  No internet service
# 17                   No                  Yes                   No
# 18                   No                  Yes                  Yes
#
#             StreamingTV      StreamingMovies        Contract PaperlessBilling  \
# 0                    No                   No  Month-to-month              Yes
# 1                    No                   No        One year               No
# 2                    No                   No  Month-to-month              Yes
# 3                    No                   No        One year               No
# 4                    No                   No  Month-to-month              Yes
# 5                   Yes                  Yes  Month-to-month              Yes
# 6                   Yes                   No  Month-to-month              Yes
# 7                    No                   No  Month-to-month               No
# 8                   Yes                  Yes  Month-to-month              Yes
# 9                    No                   No        One year               No
# 10                   No                   No  Month-to-month              Yes
# 11  No internet service  No internet service        Two year               No
# 12                  Yes                  Yes        One year               No
# 13                  Yes                  Yes  Month-to-month              Yes
# 14                  Yes                  Yes  Month-to-month              Yes
# 15                  Yes                  Yes        Two year               No
# 16  No internet service  No internet service        One year               No
# 17                  Yes                  Yes        Two year               No
# 18                   No                   No  Month-to-month               No
#
#                 PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0            Electronic check           29.85         29.85    No
# 1                Mailed check           56.95       1889.50    No
# 2                Mailed check             NaN        108.15   Yes
# 3   Bank transfer (automatic)           42.30       1840.75    No
# 4            Electronic check           70.70        151.65   Yes
# 5            Electronic check           99.65        820.50   Yes
# 6     Credit card (automatic)           89.10       1949.40    No
# 7                Mailed check           29.75        301.90    No
# 8            Electronic check          104.80       3046.05   Yes
# 9   Bank transfer (automatic)           56.15       3487.95    No
# 10               Mailed check           49.95        587.45    No
# 11    Credit card (automatic)           18.95        326.80    No
# 12    Credit card (automatic)          100.35       5681.10    No
# 13  Bank transfer (automatic)          103.70       5036.30   Yes
# 14           Electronic check          105.50       2686.05    No
# 15    Credit card (automatic)          113.25       7895.15    No
# 16               Mailed check             NaN       1022.95    No
# 17  Bank transfer (automatic)          106.70       7382.25    No
# 18    Credit card (automatic)           55.20        528.35   Yes

# %% [markdown]
# ## 5. Reshape dataframe

# %% [markdown]
# ### 5.1. Add more rows

# %%
#input
row1 = [
    {'userID': 'abc', 'name': 'John Nguyen', 'dob': '1989-02-18'},
    {'userID': 'def', 'name': 'John Smith', 'dob': '1989-03-18'}
]
row2 = [{'userID': 'ghi', 'name': 'Alan Nguyen', 'dob': '1980-02-18'}]

# create dataframes
df1 = pd.DataFrame(row1)
df2 = pd.DataFrame(row2)

# concatenate
pd.concat([df1, df2], axis=0)
# Out:
#           dob         name userID
# 0  1989-02-18  John Nguyen    abc
# 1  1989-03-18   John Smith    def
# 0  1980-02-18  Alan Nguyen    ghi

# %% [markdown]
# ### 5.2. Add more columns

# %%
# input
column1 = {
    'userID': ['abc', 'def', 'ghi'],
    'name': ['John Nguyen', 'John Smith', 'Alan Nguyen'],
    'dob':['1989-02-18', '1989-03-18', '1980-02-18']
}
column2 = {'salary': [15, 20, 30]}
# create dataframe
df1 = pd.DataFrame(column1)
df2 = pd.DataFrame(column2)

# concatenate
pd.concat([df1, df2], axis=1)
# Out:
#   userID         name         dob  salary
# 0    abc  John Nguyen  1989-02-18      15
# 1    def   John Smith  1989-03-18      20
# 2    ghi  Alan Nguyen  1980-02-18      30

# %% [markdown]
# ### 5.3. Join two dataframes

# %%
column3 = {
    'salary': [15, 20, 30],
    'userID': ['abc', 'def', 'ghi']
}
# create dataframe
df3 = pd.DataFrame(column3)

# join
df1.merge(right=df3, how='inner', on='userID')
# Out:
#   userID         name         dob  salary
# 0    abc  John Nguyen  1989-02-18      15
# 1    def   John Smith  1989-03-18      20
# 2    ghi  Alan Nguyen  1980-02-18      30

# %% [markdown]
# ## 6. Access data

# %%
# create dataframe from file and set index to 'customerID'
df = pd.read_csv('telcom.csv').set_index('customerID')

# %% [markdown]
# ### 6.1. Select rows
# #### First/last rows
# DataFrame.**head**/**tail**(number of rows)

# %%
df.head(2)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 5575-GNVDE    Male            NaN      No         No      34          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
#
#                   Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG  Month-to-month              Yes  Electronic check           29.85
# 5575-GNVDE        One year               No      Mailed check           56.95
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 5575-GNVDE       1889.50    No

# %%
df.tail(2)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#            MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 9959-WOFKT           Yes     Fiber optic            Yes           No
# 4190-MFLUW            No             DSL             No           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 9959-WOFKT              Yes          No         Yes             Yes
# 4190-MFLUW              Yes         Yes          No              No
#
#                   Contract PaperlessBilling              PaymentMethod  \
# customerID
# 9959-WOFKT        Two year               No  Bank transfer (automatic)
# 4190-MFLUW  Month-to-month               No    Credit card (automatic)
#
#             MonthlyCharges  TotalCharges Churn
# customerID
# 9959-WOFKT           106.7       7382.25    No
# 4190-MFLUW            55.2        528.35   Yes

# %% [markdown]
# #### Select row by values in index column
#
# DataFrame.**loc**\[index value\]
#
# Note that .**loc**\[ \] returns a Series while .**loc**\[\[ \]\] returns a dataframe

# %%
# Select row with customerID = '8191-XWSZG'
df.loc['8191-XWSZG'] # result will be a Series
# Out:
# gender                           Female
# SeniorCitizen                         0
# Partner                              No
# Dependents                           No
# tenure                               52
# PhoneService                        Yes
# MultipleLines                        No
# InternetService                      No
# OnlineSecurity      No internet service
# OnlineBackup        No internet service
# DeviceProtection    No internet service
# TechSupport         No internet service
# StreamingTV         No internet service
# StreamingMovies     No internet service
# Contract                       One year
# PaperlessBilling                     No
# PaymentMethod              Mailed check
# MonthlyCharges                      NaN
# TotalCharges                    1022.95
# Churn                                No
# Name: 8191-XWSZG, dtype: object

# %%
df.loc[['8191-XWSZG']] # result will be a dataframe
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 8191-XWSZG  Female            0.0      No         No      52          Yes
#
#            MultipleLines InternetService       OnlineSecurity  \
# customerID
# 8191-XWSZG            No              No  No internet service
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 8191-XWSZG  No internet service  No internet service  No internet service
#
#                     StreamingTV      StreamingMovies  Contract  \
# customerID
# 8191-XWSZG  No internet service  No internet service  One year
#
#            PaperlessBilling PaymentMethod  MonthlyCharges  TotalCharges Churn
# customerID
# 8191-XWSZG               No  Mailed check             NaN       1022.95    No

# %% [markdown]
# #### Select rows by index
# DataFrame.**iloc**\[\[ list of indices \]\]

# %%
df.iloc[[16,17]]
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
#
#            MultipleLines InternetService       OnlineSecurity  \
# customerID
# 8191-XWSZG            No              No  No internet service
# 9959-WOFKT           Yes     Fiber optic                  Yes
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
#
#                     StreamingTV      StreamingMovies  Contract  \
# customerID
# 8191-XWSZG  No internet service  No internet service  One year
# 9959-WOFKT                  Yes                  Yes  Two year
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 8191-XWSZG               No               Mailed check             NaN
# 9959-WOFKT               No  Bank transfer (automatic)           106.7
#
#             TotalCharges Churn
# customerID
# 8191-XWSZG       1022.95    No
# 9959-WOFKT       7382.25    No

# %% [markdown]
# ### 6.2 Select columns
# #### Select columns by names
# **One column**
#
# DataFrame**\[**column name**\]** or df.column_name

# %%
df['MonthlyCharges'] # result wil be a Series
# Out:
# customerID
# 7590-VHVEG     29.85
# 5575-GNVDE     56.95
# 3668-QPYBK       NaN
# 7795-CFOCW     42.30
# 9237-HQITU     70.70
# 9305-CDSKC     99.65
# 1452-KIOVK     89.10
# 6713-OKOMC     29.75
# 7892-POOKP    104.80
# 6388-TABGU     56.15
# 9763-GRSKD     49.95
# 7469-LKBCI     18.95
# 8091-TTVAX    100.35
# 0280-XJGEX    103.70
# 5129-JLPIS    105.50
# 3655-SNQYZ    113.25
# 8191-XWSZG       NaN
# 9959-WOFKT    106.70
# 4190-MFLUW     55.20
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# **More than one**
#
# DataFrame**\[\[** list of columns **\]\]**

# %%
df[['MonthlyCharges', 'TotalCharges']] # result will be a dataframe
# Out:
#             MonthlyCharges  TotalCharges
# customerID
# 7590-VHVEG           29.85         29.85
# 5575-GNVDE           56.95       1889.50
# 3668-QPYBK             NaN        108.15
# 7795-CFOCW           42.30       1840.75
# 9237-HQITU           70.70        151.65
# 9305-CDSKC           99.65        820.50
# 1452-KIOVK           89.10       1949.40
# 6713-OKOMC           29.75        301.90
# 7892-POOKP          104.80       3046.05
# 6388-TABGU           56.15       3487.95
# 9763-GRSKD           49.95        587.45
# 7469-LKBCI           18.95        326.80
# 8091-TTVAX          100.35       5681.10
# 0280-XJGEX          103.70       5036.30
# 5129-JLPIS          105.50       2686.05
# 3655-SNQYZ          113.25       7895.15
# 8191-XWSZG             NaN       1022.95
# 9959-WOFKT          106.70       7382.25
# 4190-MFLUW           55.20        528.35

# %% [markdown]
# #### Select column by index
# DataFrame.**iloc**\[:, column_indices\]

# %%
# Select first two columns
df.iloc[:, 0:2] # the same value with df.iloc[:, [0,1]]
# Out:
#             gender  SeniorCitizen
# customerID
# 7590-VHVEG  Female            0.0
# 5575-GNVDE    Male            NaN
# 3668-QPYBK    Male            0.0
# 7795-CFOCW    Male            0.0
# 9237-HQITU  Female            0.0
# 9305-CDSKC  Female            0.0
# 1452-KIOVK    Male            0.0
# 6713-OKOMC  Female            0.0
# 7892-POOKP  Female            0.0
# 6388-TABGU    Male            0.0
# 9763-GRSKD    Male            0.0
# 7469-LKBCI    Male            0.0
# 8091-TTVAX    Male            0.0
# 0280-XJGEX    Male            0.0
# 5129-JLPIS    Male            0.0
# 3655-SNQYZ  Female            0.0
# 8191-XWSZG  Female            0.0
# 9959-WOFKT    Male            0.0
# 4190-MFLUW  Female            0.0

# %% [markdown]
# ### 6.3 Select cells
# #### One cell
# **By column and row names**
#
# DataFrame\[column name\]\[row name\]

# %%
df['MonthlyCharges']['7590-VHVEG']
# Out:
# 29.85

# %% [markdown]
# **By column and row indices**
#
# DataFrame.**iloc**\[row index, column index\] or DataFrame.**iat**\[row index, column index\]

# %%
df.iloc[0,0]
# Out:
# 'Female'

# %% [markdown]
# #### A range of cells
# **By columns and rows names**
#
# DataFrame\[\[ list of columns \]\] \[ range of index values \]

# %%
df[['MonthlyCharges', 'TotalCharges', 'Churn']]['7590-VHVEG':'7795-CFOCW']
# Out:
#             MonthlyCharges  TotalCharges Churn
# customerID
# 7590-VHVEG           29.85         29.85    No
# 5575-GNVDE           56.95       1889.50    No
# 3668-QPYBK             NaN        108.15   Yes
# 7795-CFOCW           42.30       1840.75    No

# %% [markdown]
# **By column and row indices**
#
# DataFrame.**iloc**\[ row index range, column index range \]

# %%
df.iloc[0:2,1:3]
# Out:
#             SeniorCitizen Partner
# customerID
# 7590-VHVEG            0.0     Yes
# 5575-GNVDE            NaN      No

# %% [markdown]
# ### 6.4. Select rows by logical expression or filter data
# DataFrame\[ logical expression \]

# %%
df[df.gender == 'Female']
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             NaN                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling            PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes         Electronic check           29.85
# 9237-HQITU              Yes         Electronic check           70.70
# 9305-CDSKC              Yes         Electronic check           99.65
# 6713-OKOMC               No             Mailed check           29.75
# 7892-POOKP              Yes         Electronic check          104.80
# 3655-SNQYZ               No  Credit card (automatic)          113.25
# 8191-XWSZG               No             Mailed check             NaN
# 4190-MFLUW               No  Credit card (automatic)           55.20
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 9237-HQITU        151.65   Yes
# 9305-CDSKC        820.50   Yes
# 6713-OKOMC        301.90    No
# 7892-POOKP       3046.05   Yes
# 3655-SNQYZ       7895.15    No
# 8191-XWSZG       1022.95    No
# 4190-MFLUW        528.35   Yes

# %% [markdown]
# ## 7. Summarize a dataframe

# %% [markdown]
# ### 7.1. Get shape

# %%
df.shape # return (number of rows, number of columns)
# df.size will return number of cells
# Out:
# (19, 20)

# %% [markdown]
# ### 7.2. Basic information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 7590-VHVEG to 4190-MFLUW
# Data columns (total 20 columns):
# gender              19 non-null object
# SeniorCitizen       18 non-null float64
# Partner             19 non-null object
# Dependents          19 non-null object
# tenure              19 non-null int64
# PhoneService        18 non-null object
# MultipleLines       19 non-null object
# InternetService     18 non-null object
# OnlineSecurity      19 non-null object
# OnlineBackup        19 non-null object
# DeviceProtection    19 non-null object
# TechSupport         19 non-null object
# StreamingTV         19 non-null object
# StreamingMovies     19 non-null object
# Contract            19 non-null object
# PaperlessBilling    19 non-null object
# PaymentMethod       19 non-null object
# MonthlyCharges      17 non-null float64
# TotalCharges        19 non-null float64
# Churn               19 non-null object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 3.7+ KB

# %% [markdown]
# ### 7.3. Descriptive analysis
# #### For entire dataframe

# %%
df.describe()
# Out:
#        SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# count           18.0  19.000000       17.000000     19.000000
# mean             0.0  30.368421       72.520588   2356.426316
# std              0.0  23.995857       32.084474   2482.866909
# min              0.0   1.000000       18.950000     29.850000
# 25%              0.0  10.000000       49.950000    427.575000
# 50%              0.0  25.000000       70.700000   1840.750000
# 75%              0.0  50.500000      103.700000   3267.000000
# max              0.0  71.000000      113.250000   7895.150000

# %%
df.mean() # analogously df.median(), df.max(), df.min(), df.sum(), df.quantile(0.25)
# Out:
# SeniorCitizen        0.000000
# tenure              30.368421
# MonthlyCharges      72.520588
# TotalCharges      2356.426316
# dtype: float64

# %% [markdown]
# #### For specific column

# %%
df.MonthlyCharges.describe()  # the same result with df.describe().MonthlyCharges
# Out:
# count     17.000000
# mean      72.520588
# std       32.084474
# min       18.950000
# 25%       49.950000
# 50%       70.700000
# 75%      103.700000
# max      113.250000
# Name: MonthlyCharges, dtype: float64

# %%
df.MonthlyCharges.mean() # analogously df.median(), df.max(), df.min(), df.sum(), df.quantile(0.25)
# Out:
# 72.52058823529414

# %% [markdown]
# ### 7.4 Counting missing value
# #### For entire dataframe

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       1
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        1
# MultipleLines       0
# InternetService     1
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      2
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# #### For specific column

# %%
df.SeniorCitizen.isnull().sum()
# Out:
# 1

# %% [markdown]
# ### 7.5. Correlation matrix
# Only for columns with numerical type

# %%
df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen             NaN       NaN             NaN           NaN
# tenure                    NaN  1.000000        0.489321      0.863158
# MonthlyCharges            NaN  0.489321        1.000000      0.715767
# TotalCharges              NaN  0.863158        0.715767      1.000000

# %% [markdown]
# ### 7.6. check if there're duplicate rows

# %%
df.duplicated()
# Out:
# customerID
# 7590-VHVEG    False
# 5575-GNVDE    False
# 3668-QPYBK    False
# 7795-CFOCW    False
# 9237-HQITU    False
# 9305-CDSKC    False
# 1452-KIOVK    False
# 6713-OKOMC    False
# 7892-POOKP    False
# 6388-TABGU    False
# 9763-GRSKD    False
# 7469-LKBCI    False
# 8091-TTVAX    False
# 0280-XJGEX    False
# 5129-JLPIS    False
# 3655-SNQYZ    False
# 8191-XWSZG    False
# 9959-WOFKT    False
# 4190-MFLUW    False
# dtype: bool

# %%
### Uncomment and run following row to see what happens
# pd.concat([df, df.head(5)]).duplicated()

# %% [markdown]
# ### 7.7 Unique values
# Only for columns, not for dataframe
# #### Get unique values

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# #### Counting unique values

# %%
df.gender.value_counts()
# Out:
# Male      11
# Female     8
# Name: gender, dtype: int64

# %% [markdown]
# ## 8. Basic transformations for preprocessing

# %% [markdown]
# ### 8.1. Sorting

# %%
df.sort_values(by='tenure', ascending=True)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          NaN
# 7469-LKBCI    Male            0.0      No         No      16          Yes
# 1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 5129-JLPIS    Male            0.0      No         No      25          Yes
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 5575-GNVDE    Male            NaN      No         No      34          Yes
# 7795-CFOCW    Male            0.0      No         No      45           No
# 0280-XJGEX    Male            0.0      No         No      49          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 6388-TABGU    Male            0.0      No        Yes      62          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 3668-QPYBK                No             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             NaN                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 4190-MFLUW                No             DSL                   No
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 1452-KIOVK               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 5575-GNVDE                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 0280-XJGEX               Yes     Fiber optic                   No
# 8191-XWSZG                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 9959-WOFKT               Yes     Fiber optic                  Yes
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 3668-QPYBK                  Yes                   No                   No
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 6713-OKOMC                   No                   No                   No
# 4190-MFLUW                   No                  Yes                  Yes
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 1452-KIOVK                  Yes                   No                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 7892-POOKP                   No                  Yes                  Yes
# 5575-GNVDE                   No                  Yes                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 0280-XJGEX                  Yes                  Yes                   No
# 8191-XWSZG  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 6388-TABGU                  Yes                   No                   No
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 9959-WOFKT                   No                  Yes                   No
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 3668-QPYBK                   No                   No  Month-to-month
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 4190-MFLUW                   No                   No  Month-to-month
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 1452-KIOVK                  Yes                   No  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 7795-CFOCW                   No                   No        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 8191-XWSZG  No internet service  No internet service        One year
# 8091-TTVAX                  Yes                  Yes        One year
# 6388-TABGU                   No                   No        One year
# 3655-SNQYZ                  Yes                  Yes        Two year
# 9959-WOFKT                  Yes                  Yes        Two year
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 3668-QPYBK              Yes               Mailed check             NaN
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 6713-OKOMC               No               Mailed check           29.75
# 4190-MFLUW               No    Credit card (automatic)           55.20
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 5129-JLPIS              Yes           Electronic check          105.50
# 7892-POOKP              Yes           Electronic check          104.80
# 5575-GNVDE               No               Mailed check           56.95
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 8191-XWSZG               No               Mailed check             NaN
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 3668-QPYBK        108.15   Yes
# 9237-HQITU        151.65   Yes
# 9305-CDSKC        820.50   Yes
# 6713-OKOMC        301.90    No
# 4190-MFLUW        528.35   Yes
# 9763-GRSKD        587.45    No
# 7469-LKBCI        326.80    No
# 1452-KIOVK       1949.40    No
# 5129-JLPIS       2686.05    No
# 7892-POOKP       3046.05   Yes
# 5575-GNVDE       1889.50    No
# 7795-CFOCW       1840.75    No
# 0280-XJGEX       5036.30   Yes
# 8191-XWSZG       1022.95    No
# 8091-TTVAX       5681.10    No
# 6388-TABGU       3487.95    No
# 3655-SNQYZ       7895.15    No
# 9959-WOFKT       7382.25    No

# %% [markdown]
# ### 8.2. Drop duplicates

# %%
df.drop_duplicates(inplace=True) 
# By default inplace = False
# We set inplace=True to change the dataframe itself
df
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 5575-GNVDE    Male            NaN      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 7795-CFOCW    Male            0.0      No         No      45           No
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 6388-TABGU    Male            0.0      No        Yes      62          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          NaN
# 7469-LKBCI    Male            0.0      No         No      16          Yes
# 8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 0280-XJGEX    Male            0.0      No         No      49          Yes
# 5129-JLPIS    Male            0.0      No         No      25          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             NaN                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check             NaN
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check             NaN
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
# 4190-MFLUW               No    Credit card (automatic)           55.20
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 5575-GNVDE       1889.50    No
# 3668-QPYBK        108.15   Yes
# 7795-CFOCW       1840.75    No
# 9237-HQITU        151.65   Yes
# 9305-CDSKC        820.50   Yes
# 1452-KIOVK       1949.40    No
# 6713-OKOMC        301.90    No
# 7892-POOKP       3046.05   Yes
# 6388-TABGU       3487.95    No
# 9763-GRSKD        587.45    No
# 7469-LKBCI        326.80    No
# 8091-TTVAX       5681.10    No
# 0280-XJGEX       5036.30   Yes
# 5129-JLPIS       2686.05    No
# 3655-SNQYZ       7895.15    No
# 8191-XWSZG       1022.95    No
# 9959-WOFKT       7382.25    No
# 4190-MFLUW        528.35   Yes

# %% [markdown]
# ### 8.3. Dealing with missing value
# #### 8.3.1. Drop missing value

# %%
dfs = df.copy()
dfs.dropna(inplace=True)
pd.DataFrame({'Intput missing value count': df.isnull().sum(), 
              'Output missing value count': dfs.isnull().sum()})
# Out:
#                   Intput missing value count  Output missing value count
# gender                                     0                           0
# SeniorCitizen                              1                           0
# Partner                                    0                           0
# Dependents                                 0                           0
# tenure                                     0                           0
# PhoneService                               1                           0
# MultipleLines                              0                           0
# InternetService                            1                           0
# OnlineSecurity                             0                           0
# OnlineBackup                               0                           0
# DeviceProtection                           0                           0
# TechSupport                                0                           0
# StreamingTV                                0                           0
# StreamingMovies                            0                           0
# Contract                                   0                           0
# PaperlessBilling                           0                           0
# PaymentMethod                              0                           0
# MonthlyCharges                             2                           0
# TotalCharges                               0                           0
# Churn                                      0                           0

# %%
# check the shape
print('Input dataframe shape:', df.shape,'\nOutput dataframe shape:', dfs.shape)
# Out:
# Input dataframe shape: (19, 20)
# Output dataframe shape: (14, 20)

# %% [markdown]
# #### 8.3.2 Fill missing value

# %%
# fill with entire dataframe
dfs = df.copy()
# values to fill in each column
filling_values = {
    'SeniorCitizen': df.SeniorCitizen.mean(),
    'PhoneService': df.PhoneService.mode()[0], 
    'InternetService': df.InternetService.mode()[0],
    'MonthlyCharges': df.MonthlyCharges.median()
}

# fill
dfs.fillna(value=filling_values, inplace=True)

# %%
# Rows with missing values in input dataframe
df_nan = df[df.isnull().max(axis=1)]
df_nan
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 5575-GNVDE    Male            NaN      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          NaN
# 8191-XWSZG  Female            0.0      No         No      52          Yes
#
#            MultipleLines InternetService       OnlineSecurity  \
# customerID
# 5575-GNVDE            No             DSL                  Yes
# 3668-QPYBK            No             DSL                  Yes
# 9305-CDSKC           Yes             NaN                   No
# 9763-GRSKD            No             DSL                  Yes
# 8191-XWSZG            No              No  No internet service
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 9763-GRSKD                   No                   No                   No
# 8191-XWSZG  No internet service  No internet service  No internet service
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 9763-GRSKD                   No                   No  Month-to-month
# 8191-XWSZG  No internet service  No internet service        One year
#
#            PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 5575-GNVDE               No      Mailed check           56.95       1889.50
# 3668-QPYBK              Yes      Mailed check             NaN        108.15
# 9305-CDSKC              Yes  Electronic check           99.65        820.50
# 9763-GRSKD              Yes      Mailed check           49.95        587.45
# 8191-XWSZG               No      Mailed check             NaN       1022.95
#
#            Churn
# customerID
# 5575-GNVDE    No
# 3668-QPYBK   Yes
# 9305-CDSKC   Yes
# 9763-GRSKD    No
# 8191-XWSZG    No

# %%
# These rows in output dataframe
dfs.loc[df_nan.index]
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 5575-GNVDE    Male            0.0      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
#
#            MultipleLines InternetService       OnlineSecurity  \
# customerID
# 5575-GNVDE            No             DSL                  Yes
# 3668-QPYBK            No             DSL                  Yes
# 9305-CDSKC           Yes             DSL                   No
# 9763-GRSKD            No             DSL                  Yes
# 8191-XWSZG            No              No  No internet service
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 9763-GRSKD                   No                   No                   No
# 8191-XWSZG  No internet service  No internet service  No internet service
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 9763-GRSKD                   No                   No  Month-to-month
# 8191-XWSZG  No internet service  No internet service        One year
#
#            PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 5575-GNVDE               No      Mailed check           56.95       1889.50
# 3668-QPYBK              Yes      Mailed check           70.70        108.15
# 9305-CDSKC              Yes  Electronic check           99.65        820.50
# 9763-GRSKD              Yes      Mailed check           49.95        587.45
# 8191-XWSZG               No      Mailed check           70.70       1022.95
#
#            Churn
# customerID
# 5575-GNVDE    No
# 3668-QPYBK   Yes
# 9305-CDSKC   Yes
# 9763-GRSKD    No
# 8191-XWSZG    No

# %% [markdown]
# To fill missing value for a specific column
#
# DataFrame.column_name.**fillna**(filling_value)

# %% [markdown]
# ### 8.4. Changing a column
# df.column_name = operation(df.column_name)

# %% [markdown]
# #### 8.4.1. Normarlize or scale to [0..1]
#
# $$\text{Column}=\frac{\text{Column}-\text{Column}_{min}}{\text{Column}_{max}-\text{Column}_{min}}$$

# %%
dfa = dfs.copy()
max_ = dfa.MonthlyCharges.max()
min_ = dfa.MonthlyCharges.min()
dfa.MonthlyCharges = (dfa.MonthlyCharges-min_)/(max_-min_)
dfa
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 5575-GNVDE    Male            0.0      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 7795-CFOCW    Male            0.0      No         No      45           No
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 6388-TABGU    Male            0.0      No        Yes      62          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          Yes
# 7469-LKBCI    Male            0.0      No         No      16          Yes
# 8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 0280-XJGEX    Male            0.0      No         No      49          Yes
# 5129-JLPIS    Male            0.0      No         No      25          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             DSL                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check        0.115589
# 5575-GNVDE               No               Mailed check        0.402969
# 3668-QPYBK              Yes               Mailed check        0.548780
# 7795-CFOCW               No  Bank transfer (automatic)        0.247614
# 9237-HQITU              Yes           Electronic check        0.548780
# 9305-CDSKC              Yes           Electronic check        0.855779
# 1452-KIOVK              Yes    Credit card (automatic)        0.743902
# 6713-OKOMC               No               Mailed check        0.114528
# 7892-POOKP              Yes           Electronic check        0.910392
# 6388-TABGU               No  Bank transfer (automatic)        0.394486
# 9763-GRSKD              Yes               Mailed check        0.328738
# 7469-LKBCI               No    Credit card (automatic)        0.000000
# 8091-TTVAX               No    Credit card (automatic)        0.863203
# 0280-XJGEX              Yes  Bank transfer (automatic)        0.898727
# 5129-JLPIS              Yes           Electronic check        0.917815
# 3655-SNQYZ               No    Credit card (automatic)        1.000000
# 8191-XWSZG               No               Mailed check        0.548780
# 9959-WOFKT               No  Bank transfer (automatic)        0.930541
# 4190-MFLUW               No    Credit card (automatic)        0.384411
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 5575-GNVDE       1889.50    No
# 3668-QPYBK        108.15   Yes
# 7795-CFOCW       1840.75    No
# 9237-HQITU        151.65   Yes
# 9305-CDSKC        820.50   Yes
# 1452-KIOVK       1949.40    No
# 6713-OKOMC        301.90    No
# 7892-POOKP       3046.05   Yes
# 6388-TABGU       3487.95    No
# 9763-GRSKD        587.45    No
# 7469-LKBCI        326.80    No
# 8091-TTVAX       5681.10    No
# 0280-XJGEX       5036.30   Yes
# 5129-JLPIS       2686.05    No
# 3655-SNQYZ       7895.15    No
# 8191-XWSZG       1022.95    No
# 9959-WOFKT       7382.25    No
# 4190-MFLUW        528.35   Yes

# %% [markdown]
# #### 8.4.2. Mapping for a categorical column

# %%
dfa = dfs.copy()
dfa.gender = dfa.gender.map({'Female': 0, 'Male': 1})
dfa
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG       0            0.0     Yes         No       1           No
# 5575-GNVDE       1            0.0      No         No      34          Yes
# 3668-QPYBK       1            0.0      No         No       2          Yes
# 7795-CFOCW       1            0.0      No         No      45           No
# 9237-HQITU       0            0.0      No         No       2          Yes
# 9305-CDSKC       0            0.0      No         No       8          Yes
# 1452-KIOVK       1            0.0      No        Yes      22          Yes
# 6713-OKOMC       0            0.0      No         No      10           No
# 7892-POOKP       0            0.0     Yes         No      28          Yes
# 6388-TABGU       1            0.0      No        Yes      62          Yes
# 9763-GRSKD       1            0.0     Yes        Yes      13          Yes
# 7469-LKBCI       1            0.0      No         No      16          Yes
# 8091-TTVAX       1            0.0     Yes         No      58          Yes
# 0280-XJGEX       1            0.0      No         No      49          Yes
# 5129-JLPIS       1            0.0      No         No      25          Yes
# 3655-SNQYZ       0            0.0     Yes        Yes      69          Yes
# 8191-XWSZG       0            0.0      No         No      52          Yes
# 9959-WOFKT       1            0.0      No        Yes      71          Yes
# 4190-MFLUW       0            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             DSL                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check           70.70
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check           70.70
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
# 4190-MFLUW               No    Credit card (automatic)           55.20
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 5575-GNVDE       1889.50    No
# 3668-QPYBK        108.15   Yes
# 7795-CFOCW       1840.75    No
# 9237-HQITU        151.65   Yes
# 9305-CDSKC        820.50   Yes
# 1452-KIOVK       1949.40    No
# 6713-OKOMC        301.90    No
# 7892-POOKP       3046.05   Yes
# 6388-TABGU       3487.95    No
# 9763-GRSKD        587.45    No
# 7469-LKBCI        326.80    No
# 8091-TTVAX       5681.10    No
# 0280-XJGEX       5036.30   Yes
# 5129-JLPIS       2686.05    No
# 3655-SNQYZ       7895.15    No
# 8191-XWSZG       1022.95    No
# 9959-WOFKT       7382.25    No
# 4190-MFLUW        528.35   Yes

# %% [markdown]
# #### 8.4.3. Apply a function

# %%
def tenure_to_group(tenure):
    if tenure < 30:
        return 0
    elif tenure < 60:
        return 1
    else:
        return 2
    
dfa = dfs.copy()
dfa.tenure = dfa.tenure.apply(lambda tenure: tenure_to_group(tenure))
dfa
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       0           No
# 5575-GNVDE    Male            0.0      No         No       1          Yes
# 3668-QPYBK    Male            0.0      No         No       0          Yes
# 7795-CFOCW    Male            0.0      No         No       1           No
# 9237-HQITU  Female            0.0      No         No       0          Yes
# 9305-CDSKC  Female            0.0      No         No       0          Yes
# 1452-KIOVK    Male            0.0      No        Yes       0          Yes
# 6713-OKOMC  Female            0.0      No         No       0           No
# 7892-POOKP  Female            0.0     Yes         No       0          Yes
# 6388-TABGU    Male            0.0      No        Yes       2          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes       0          Yes
# 7469-LKBCI    Male            0.0      No         No       0          Yes
# 8091-TTVAX    Male            0.0     Yes         No       1          Yes
# 0280-XJGEX    Male            0.0      No         No       1          Yes
# 5129-JLPIS    Male            0.0      No         No       0          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes       2          Yes
# 8191-XWSZG  Female            0.0      No         No       1          Yes
# 9959-WOFKT    Male            0.0      No        Yes       2          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes       0          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             DSL                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check           70.70
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check           70.70
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
# 4190-MFLUW               No    Credit card (automatic)           55.20
#
#             TotalCharges Churn
# customerID
# 7590-VHVEG         29.85    No
# 5575-GNVDE       1889.50    No
# 3668-QPYBK        108.15   Yes
# 7795-CFOCW       1840.75    No
# 9237-HQITU        151.65   Yes
# 9305-CDSKC        820.50   Yes
# 1452-KIOVK       1949.40    No
# 6713-OKOMC        301.90    No
# 7892-POOKP       3046.05   Yes
# 6388-TABGU       3487.95    No
# 9763-GRSKD        587.45    No
# 7469-LKBCI        326.80    No
# 8091-TTVAX       5681.10    No
# 0280-XJGEX       5036.30   Yes
# 5129-JLPIS       2686.05    No
# 3655-SNQYZ       7895.15    No
# 8191-XWSZG       1022.95    No
# 9959-WOFKT       7382.25    No
# 4190-MFLUW        528.35   Yes

# %% [markdown]
# ### 8.5. Create new column
# DataFrame\['new column name'\] = operation(dataframe/columns)
#
# #### Standardize a numeric column
# $$\text{Column}=\frac{\text{Column}-\text{Column}_{mean}}{\text{Column}_{std}}$$

# %%
# Standardize a numeric column and assign to new column
import numpy as np
dfa = dfs.copy()
count = dfa.shape[0]
mean = dfa.TotalCharges.mean()
std_adj = dfa.TotalCharges.std()*np.sqrt((count-1)/count)
dfa['TotalCharges_std'] = (dfa.TotalCharges - mean)/std_adj
dfa
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 5575-GNVDE    Male            0.0      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 7795-CFOCW    Male            0.0      No         No      45           No
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 6388-TABGU    Male            0.0      No        Yes      62          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          Yes
# 7469-LKBCI    Male            0.0      No         No      16          Yes
# 8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 0280-XJGEX    Male            0.0      No         No      49          Yes
# 5129-JLPIS    Male            0.0      No         No      25          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             DSL                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check           70.70
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check           70.70
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
# 4190-MFLUW               No    Credit card (automatic)           55.20
#
#             TotalCharges Churn  TotalCharges_std
# customerID
# 7590-VHVEG         29.85    No         -0.962730
# 5575-GNVDE       1889.50    No         -0.193213
# 3668-QPYBK        108.15   Yes         -0.930330
# 7795-CFOCW       1840.75    No         -0.213385
# 9237-HQITU        151.65   Yes         -0.912329
# 9305-CDSKC        820.50   Yes         -0.635561
# 1452-KIOVK       1949.40    No         -0.168426
# 6713-OKOMC        301.90    No         -0.850156
# 7892-POOKP       3046.05   Yes          0.285364
# 6388-TABGU       3487.95    No          0.468221
# 9763-GRSKD        587.45    No         -0.731997
# 7469-LKBCI        326.80    No         -0.839853
# 8091-TTVAX       5681.10    No          1.375739
# 0280-XJGEX       5036.30   Yes          1.108923
# 5129-JLPIS       2686.05    No          0.136397
# 3655-SNQYZ       7895.15    No          2.291906
# 8191-XWSZG       1022.95    No         -0.551788
# 9959-WOFKT       7382.25    No          2.079670
# 4190-MFLUW        528.35   Yes         -0.756452

# %%
# Standardize with Scikit-learn 
from sklearn.preprocessing import StandardScaler
dfa['TotalCharges_std'] = StandardScaler().fit_transform(dfa[['TotalCharges']]).reshape(1, -1)[0]
dfa
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 5575-GNVDE    Male            0.0      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 7795-CFOCW    Male            0.0      No         No      45           No
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 6388-TABGU    Male            0.0      No        Yes      62          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          Yes
# 7469-LKBCI    Male            0.0      No         No      16          Yes
# 8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 0280-XJGEX    Male            0.0      No         No      49          Yes
# 5129-JLPIS    Male            0.0      No         No      25          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             DSL                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check           70.70
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check           70.70
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
# 4190-MFLUW               No    Credit card (automatic)           55.20
#
#             TotalCharges Churn  TotalCharges_std
# customerID
# 7590-VHVEG         29.85    No         -0.962730
# 5575-GNVDE       1889.50    No         -0.193213
# 3668-QPYBK        108.15   Yes         -0.930330
# 7795-CFOCW       1840.75    No         -0.213385
# 9237-HQITU        151.65   Yes         -0.912329
# 9305-CDSKC        820.50   Yes         -0.635561
# 1452-KIOVK       1949.40    No         -0.168426
# 6713-OKOMC        301.90    No         -0.850156
# 7892-POOKP       3046.05   Yes          0.285364
# 6388-TABGU       3487.95    No          0.468221
# 9763-GRSKD        587.45    No         -0.731997
# 7469-LKBCI        326.80    No         -0.839853
# 8091-TTVAX       5681.10    No          1.375739
# 0280-XJGEX       5036.30   Yes          1.108923
# 5129-JLPIS       2686.05    No          0.136397
# 3655-SNQYZ       7895.15    No          2.291906
# 8191-XWSZG       1022.95    No         -0.551788
# 9959-WOFKT       7382.25    No          2.079670
# 4190-MFLUW        528.35   Yes         -0.756452

# %% [markdown]
# ### 8.6. One-hot endcode categorical column

# %%
dfa = dfs.copy()
dfa = pd.get_dummies(data=dfa, columns=['PaymentMethod'])
dfa
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No       1           No
# 5575-GNVDE    Male            0.0      No         No      34          Yes
# 3668-QPYBK    Male            0.0      No         No       2          Yes
# 7795-CFOCW    Male            0.0      No         No      45           No
# 9237-HQITU  Female            0.0      No         No       2          Yes
# 9305-CDSKC  Female            0.0      No         No       8          Yes
# 1452-KIOVK    Male            0.0      No        Yes      22          Yes
# 6713-OKOMC  Female            0.0      No         No      10           No
# 7892-POOKP  Female            0.0     Yes         No      28          Yes
# 6388-TABGU    Male            0.0      No        Yes      62          Yes
# 9763-GRSKD    Male            0.0     Yes        Yes      13          Yes
# 7469-LKBCI    Male            0.0      No         No      16          Yes
# 8091-TTVAX    Male            0.0     Yes         No      58          Yes
# 0280-XJGEX    Male            0.0      No         No      49          Yes
# 5129-JLPIS    Male            0.0      No         No      25          Yes
# 3655-SNQYZ  Female            0.0     Yes        Yes      69          Yes
# 8191-XWSZG  Female            0.0      No         No      52          Yes
# 9959-WOFKT    Male            0.0      No        Yes      71          Yes
# 4190-MFLUW  Female            0.0     Yes        Yes      10          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes             DSL                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
#
#            PaperlessBilling  MonthlyCharges  TotalCharges Churn  \
# customerID
# 7590-VHVEG              Yes           29.85         29.85    No
# 5575-GNVDE               No           56.95       1889.50    No
# 3668-QPYBK              Yes           70.70        108.15   Yes
# 7795-CFOCW               No           42.30       1840.75    No
# 9237-HQITU              Yes           70.70        151.65   Yes
# 9305-CDSKC              Yes           99.65        820.50   Yes
# 1452-KIOVK              Yes           89.10       1949.40    No
# 6713-OKOMC               No           29.75        301.90    No
# 7892-POOKP              Yes          104.80       3046.05   Yes
# 6388-TABGU               No           56.15       3487.95    No
# 9763-GRSKD              Yes           49.95        587.45    No
# 7469-LKBCI               No           18.95        326.80    No
# 8091-TTVAX               No          100.35       5681.10    No
# 0280-XJGEX              Yes          103.70       5036.30   Yes
# 5129-JLPIS              Yes          105.50       2686.05    No
# 3655-SNQYZ               No          113.25       7895.15    No
# 8191-XWSZG               No           70.70       1022.95    No
# 9959-WOFKT               No          106.70       7382.25    No
# 4190-MFLUW               No           55.20        528.35   Yes
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                        0
# 5575-GNVDE                                        0
# 3668-QPYBK                                        0
# 7795-CFOCW                                        1
# 9237-HQITU                                        0
# 9305-CDSKC                                        0
# 1452-KIOVK                                        0
# 6713-OKOMC                                        0
# 7892-POOKP                                        0
# 6388-TABGU                                        1
# 9763-GRSKD                                        0
# 7469-LKBCI                                        0
# 8091-TTVAX                                        0
# 0280-XJGEX                                        1
# 5129-JLPIS                                        0
# 3655-SNQYZ                                        0
# 8191-XWSZG                                        0
# 9959-WOFKT                                        1
# 4190-MFLUW                                        0
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                      0
# 5575-GNVDE                                      0
# 3668-QPYBK                                      0
# 7795-CFOCW                                      0
# 9237-HQITU                                      0
# 9305-CDSKC                                      0
# 1452-KIOVK                                      1
# 6713-OKOMC                                      0
# 7892-POOKP                                      0
# 6388-TABGU                                      0
# 9763-GRSKD                                      0
# 7469-LKBCI                                      1
# 8091-TTVAX                                      1
# 0280-XJGEX                                      0
# 5129-JLPIS                                      0
# 3655-SNQYZ                                      1
# 8191-XWSZG                                      0
# 9959-WOFKT                                      0
# 4190-MFLUW                                      1
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                               1                           0
# 5575-GNVDE                               0                           1
# 3668-QPYBK                               0                           1
# 7795-CFOCW                               0                           0
# 9237-HQITU                               1                           0
# 9305-CDSKC                               1                           0
# 1452-KIOVK                               0                           0
# 6713-OKOMC                               0                           1
# 7892-POOKP                               1                           0
# 6388-TABGU                               0                           0
# 9763-GRSKD                               0                           1
# 7469-LKBCI                               0                           0
# 8091-TTVAX                               0                           0
# 0280-XJGEX                               0                           0
# 5129-JLPIS                               1                           0
# 3655-SNQYZ                               0                           0
# 8191-XWSZG                               0                           1
# 9959-WOFKT                               0                           0
# 4190-MFLUW                               0                           0
